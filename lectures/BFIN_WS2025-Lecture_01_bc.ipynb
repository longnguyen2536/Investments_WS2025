# %% [markdown]
# <center>
# <img src="../images/fscampus_small2.png" width="1200"/>
# </center>
#
# <center>
#
# # Investments
#
# ***Finance 2 - BFIN***
#
# **Dr. Omer Cayirli**
#
# Lecturer in Empirical Finance
#
# omer.cayirli@vgu.edu.vn
# </center>
#
#
# ---

# %% [markdown]
# ## Lecture 01
# ---

# %% [markdown]
# ### Outline
# * Intro
#   * Content & Objectives
#   * Course Materials
# * Rules of the Game
#   * Expectations & Norms
#   * Attendance & Participation
#   * Grading
# * Lecture
#   * The Investment Environment; Asset Classes and Financial Instruments
#
# ---

# %% [markdown]
# ### Intro
# * Course Content
#   * The Investment Environment
#     * Asset Classes and Financial Instruments
#   * Fixed-Income Securities
#   * Portfolio Theory and Practice
#   * Asset Pricing Models
#     * Index Models and The Capital Asset Pricing Model
#     * Arbitrage Pricing Theory
#     * Multifactor Models of Risk and Return
#   * The Efficient Market Hypothesis
#     * Behavioral Finance
#     * Empirical Evidence on Security Returns
#   * Derivatives
#     * Futures, Forwards, and Swaps
#     * Option Markets and Option Valuation
#
# ---

# %% [markdown]
# ### Intro
# * Objectives
#   * The analytical tools and theoretical concepts necessary for
#     * Making good investment decisions,
#     * Understanding the paradigms by which financial securities are valued.
#   * The students should
#     * acquire basic professional and methodological skills in the field of financial economics.
#     * be able to name and explain the characteristics and modes of operation of the most important financial instruments and the respective financial markets.
#     * possess the knowledge to present the most important models for the analysis of financial instruments, their assumptions as well as their limitations and apply the models to practical examples.
#     * be capable of presenting, interpreting and applying simple risk management strategies for securities portfolios.
#   * In this context,
#     * The lectures will explore issues closely related to asset pricing, asset allocation, and risk management.
#
# ---

# %% [markdown]
# ### Intro
# * Course Materials
#   * Books
#     * BKM, Bodie, Z., A. Kane and A. Marcus, Investments, 2021, 12th edition, International Student Edition, McGraw-Hill.
#   * Lecture slides
#     * Before each class (without exercises)
#     * Updated after class (with exercises, if any).
#
# ---

# %% [markdown]
# ### Rules
# * Expectations & Norms
#   * Be prepared for the class
#     * Assigned readings
#     * Previous class(es)
#   * Avoid scholastic offenses and adhere to the student conduct policies
# * Attendance
#   * Lectures will not be based solely on the book.
#   * Attendance and active class participation are important for achieving the learning goals.
#   * Students must comply with the University's attendance policy to earn credits for this course.
#   * Remember!: "Late arrivals to class are disruptive."
# * Participation
#   * We will have interactive classes and you are expected to contribute.
#   * You cannot contribute if you don't attend and participate.
#   * Cold calls should be expected.
#
# ---

# %% [markdown]
# # <center>Questions?</center>
#
# ---

# %% [markdown]
# ### The Investment Environment
# * Real Assets vs. Financial Assets
#   * Real Assets
#     * Have productive capacity
#   * Financial Assets
#     * Claims on real assets
#     * Do not contribute directly to productive capacity
#
# <center>
# <img src="../images/financial_assets.png" width="900"/>
# </center>
#
# ---

# %% [markdown]
# ### The Investment Environment
# * Financial Markets and the Economy
#   * The Informational Role
#     * Stock prices reflect "collective” assessment of a firm's current performance and future prospects.
#   * Consumption Timing
#     * Use securities to store wealth and transfer consumption to the future
#       * Store of wealth in financial assets
#       * Buying/selling in different life periods
#   * Allocation of Risk
#     * Allows investors to select securities consistent with their risk preferences
#       * From high to low (shares/bonds) to different categories of investors
#   * Corporate Governance
#     * Monitoring by large investors and security analysts
#     * Takeover threat
#
# ---

# %% [markdown]
# ### The Investment Environment
# * Financial Markets and the Economy
#   * Capital markets recognize and drive funds to the best ideas and enterprises.
#   * Markets facilitate the transfer of funds from those who seek a return on their assets to those who need capital to expand.
#   * Capital, raised through equity and debt, can be used to
#     * grow businesses,
#     * finance investments in new property, equipment, technology,
#     * fund infrastructure projects.
#   * Individuals and businesses can invest in securities to generate wealth.
#
# ---

# %% [markdown]
# ### The Investment Environment
# * The Investment Process
#   * Asset allocation
#     * Choice among broad asset classes (stocks; bonds; commodities; real estate; etc.)
#   * Security selection
#     * Choice of securities within each asset class
#   * Portfolio: Collection of investment assets
#     * "Top-down" approach
#       * Asset allocation followed by security analysis
#     * "Bottom-up” approach
#       * Investment based solely on the price-attractiveness
#       * Not much interest in asset allocation
#
# ---

# %% [markdown]
# ### The Investment Environment
# * Competitive Markets
#   * Risk-Return Trade-Off
#     * Higher-risk assets are priced to offer higher expected returns than lower-risk assets
#     * Expected returns are compensation for accepting the discomfort of higher risk.
#   * Efficient Markets
#     * Prices quickly adjust to all relevant information
#     * There should be neither underpriced nor overpriced securities
#   * Passive Management
#     * Holding a highly diversified portfolio
#     * No attempt to find undervalued securities
#     * No attempt to time the market
#   * Active Management
#     * Finding mispriced securities
#     * Timing the market
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments: Fixed Income
#
# <center>
# <img src="../images/slide_1/pic_1.png" width="900"/>
# </center>
#
# * The Money Market
#   * Short-term
#   * Liquid
#   * Generally low risk
# * The Capital Market
#   * Long-term
#   * Liquidity (depends)
#   * Higher risk/return
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
# * Fixed Income
#   * The Money Market
#     * Treasury Bills
#     * Certificates of Deposit
#     * Commercial Paper
#     * Eurodollars
#     * Repos and Reverses
#     * Federal Funds
#     * SOFR-linked Instruments
#     * Money Market Funds
#   * The Capital Market
#     * Treasury Notes and Bonds
#     * Inflation-Protected Treasury Bonds
#     * Federal Agency Debt
#     * International Bonds
#     * Municipal Bonds
#     * Corporate Bonds
#     * Asset-Backed Securities
#     * Mortgage-Backed Securities
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments: Equity
# <center>
# <img src="../images/slide_1/pic_2.png" width="640">
# </center>
#
# * Common stock
#   * Ownership
#   * Residual claim
#   * Limited liability
# * Preferred stock:
#   * Perpetuity (infinite-maturity bond)
#   * Fixed dividends (Like a bond)
#   * The firm retains discretion to make the dividend payments to the preferred stockholders
#   * Priority over common
#   * Tax treatment
# * American Depository Receipts (ADR)
#   * Certificates traded in U.S. markets that represent ownership in shares of a foreign company
#   * Makes it easier for foreign firms to satisfy U.S. security registration requirements
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments: Derivatives
#
# <center>
# <img src="../images/slide_1/pic_3.png" width="900">
# </center>
#
# * A derivative is a security that gets its value from the value of another asset, such as commodity prices, bond and stock prices, or market index values
#   * Their values derive from the values of other assets.
#   * Also called contingent claims because their payoffs are contingent on the value of other values.
# * Options: Right to sell/buy
# * Futures/Forwards: Obligation to deliver/receive in exchange for cash
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments: Derivatives
# * Options
#   * A call option gives its holder the right to purchase an asset for a specified price, called the exercise or strike price, on or before a specified expiration date.
#   * A put option gives its holder the right to sell an asset for a specified exercise price on or before a specified expiration date.
#   * Options may or may not be exercised.
# * Futures/Forwards
#   * A futures contract calls for delivery of an asset (or, in some cases, its cash value) at a specified delivery or maturity date for an agreed-upon price, called the futures price, to be paid at contract maturity.
#     * The long position is held by the party who commits to purchasing the asset on the delivery date.
#     * The party who takes the short position commits to delivering the asset at contract maturity.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# <center>
# <img src="../images/slide_1/pic_4.png" width="1000" height="300">
# </center>
#
# Source: [2025 SIFMA Capital Markets Factbook](https://www.sifma.org/wp-content/uploads/2024/07/2025-SIFMA-Capital-Markets-Factbook.pdf)
#
# Note: As of 2024, China 2022. Euro Area = 20 EU-member states using the Euro. Debt securities = financial liabilities (OECD classification). Other financing, ex-China = insurance reserves, trade credits and trade advances; other financing, China = bankers' acceptances, FDI, other foreign A/D, misc. and errors. Corporate bonds = issued via DCM divisions of financial institutions. US loans = bank loans only.
#
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
# <center>
# <img src="../images/slide_1/pic_5.png">
# </center>
#
#
# Source: [2025 SIFMA Capital Markets Factbook](https://www.sifma.org/wp-content/uploads/2024/07/2025-SIFMA-Capital-Markets-Factbook.pdf)
#
# Note:  DM = developed markets, EM = emerging markets, DM/EM exclude countries listed in the chart. HK: Hongkong.
#
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# <center>
# <img src="../images/slide_1/pic_6.png" width="840">
# </center>
#
#
# Source: [2025 SIFMA Capital Markets Factbook](https://www.sifma.org/wp-content/uploads/2024/07/2025-SIFMA-Capital-Markets-Factbook.pdf)
#
# Note: Includes interest rates, foreign exchange, equity linked, commodities, credit, and credit default swaps.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# <center>
# <img src="../images/slide_1/pic_7.png" width="1080">
# </center>
#
#
# Source: [2025 SIFMA Capital Markets Factbook](https://www.sifma.org/wp-content/uploads/2024/07/2025-SIFMA-Capital-Markets-Factbook.pdf)
#
# Note: Long-term includes securities with maturity >13 months; global equity issuance includes non-convertible IPOs and follow-on equity deals, excludes preferred shares, rights issues, closed-end funds, business development companies, and special purpose acquisition companies.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# <center>
# <img src="../images/slide_1/pic_8.png" width="960">
# </center>
#
#
# Source: [2025 SIFMA Capital Markets Factbook](https://www.sifma.org/wp-content/uploads/2024/07/2025-SIFMA-Capital-Markets-Factbook.pdf)
#
# Note:  Long-term includes securities with maturity >13 months; global equity issuance includes non-convertible IPOs and follow-on equity deals, excludes preferred shares, rights issues, closed-end funds, business development companies, and special purpose acquisition companies.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# <center>
# <img src="../images/slide_1/pic_9.png" width="960">
# </center>
#
#
# Source: [2025 SIFMA Capital Markets Factbook](https://www.sifma.org/wp-content/uploads/2024/07/2025-SIFMA-Capital-Markets-Factbook.pdf)
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# <center>
# <img src="../images/slide_1/pic_10.png" width="960">
# </center>
#
#
# Source: [2025 SIFMA Capital Markets Factbook](https://www.sifma.org/wp-content/uploads/2024/07/2025-SIFMA-Capital-Markets-Factbook.pdf)
#
# Note: End of year closing price, local currency.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# * Which of the following best describes a key characteristic of common stock that typically distinguishes it from preferred stock?
#
#   a. It pays a fixed, predetermined dividend to its holders.
#
#   b. It gives the holder priority over all other equity holders in the case of a company's liquidation.
#
#   c. It represents an ownership interest that grants voting rights and a residual claim on the firm's earnings and assets.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# * An investor believes that the key to generating superior returns is to identify specific companies that are fundamentally undervalued, irrespective of the current macroeconomic climate or which industry sector is in favor. This investor's strategy is most consistent with:
#
#   a. A passive management style focused on asset allocation.
#
#   b. A "top-down" investment process driven by economic forecasting.
#
#   c. A "bottom-up" investment process focused on security selection.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# * What does a call option provide to its holder?
#
#   a. The right to sell an asset for a specified price on or before a specified expiration date.
#
#   b. An obligation to buy an asset for an agreed-upon price at a specified future date.
#
#   c. The right to buy an asset for a specified price on or before a specified expiration date.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# * Which of the following correctly describes a reverse repurchase agreement from the cash-lender’s perspective?
#
#   a. The purchase of a security with a commitment to resell the same security at a specified future date and a designated price.
#
#   b. The sale of a security with a commitment to repurchase the same security at a specified future date and a designated price.
#
#   c. The purchase of a security with no obligation to resell, effectively making it a permanent transaction.
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# * What would you expect to happen to the spread between yields on commercial paper and Treasury bills if the economy were to enter a steep recession?
#
# * Assuming that all other relevant features of the stocks and options are identical, which security should sell at a greater price?
#
#   * A 10-year Treasury bond with a 6% coupon rate versus a 10-year T-bond with a 5% coupon.
#
#   * A 3-month expiration call option with an exercise price of $40 versus a 3-month call on the same stock with an exercise price of $45.
#
#   * A 3-month expiration put option with an exercise price of $40 versus a 3-month put on the same stock with an exercise price of $45.
#
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# * Both a call and a put are traded on shares of Gamma Technologies; both have strike prices of $75$ and an expiration of 1 month. What will be the profit for an investor who buys the call for a premium of $3$ in the following scenarios for the stock price in 1 month? What will be the profit in each scenario for an investor who buys the put for a premium of $4$?
#
#   a. $65$
#
#   b. $70$
#
#   c. $75$
#
#   d. $80$
#
#   e. $85$
#
# * What is the difference between a put option and a short position in a futures contract?
#
# * What is the difference between a call option and a long position in a futures contract?
#
# ---

# %% [markdown]
# ### Asset Classes and Financial Instruments
#
# Apex BioVentures is a start-up biotech firm. It currently owns laboratory equipment worth $80,000$ and has cash on hand of $50,000$ contributed by its founders. For each of the following transactions, identify the real and/or financial assets that trade hands. Are any financial assets created or destroyed in the transaction?
#
# *   Apex issues corporate bonds to raise capital. It receives $200,000$ in cash and creates a corresponding liability to pay back the bondholders over 5 years.
# *   Apex uses the cash from the bond sale plus $40,000$ of its own funds to finance the research and development of a new drug, securing a patent for the formula.
# *   Apex sells the patent to Global Pharma Inc., a major pharmaceutical company. Apex accepts payment in the form of 5,000 shares of Global Pharma stock.
# *   Apex sells all 5,000 shares of stock for $60$ per share and uses part of the cash proceeds to pay off its outstanding corporate bonds.
#
# ---

# %% [markdown]
# ### What is next?
# * Fixed-Income Securities
#   * Readings: Ch. 14 & 15
#
# ---
